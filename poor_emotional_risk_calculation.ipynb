# %% [markdown]
# ![poor_emotional_risk_calculation.png](attachment:801828b7-a9b7-4422-b841-2d5f2f771cf8.png)

# %% [markdown]
# # Poor Emotional Regulation Control (PERC) Calculation
#
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %%
first_install = False 
if first_install:
    # !pip install schedule
    # !pip install zipp

# %%
import os
import schedule
from datetime import datetime
import quick_logger as ql
import talking_code as tc 
import file_manager as fm 
import time
import zipfile
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-03-17 at 20:42:46.771037

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'poor_emotional_risk_calculation'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging and debugging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process poor_emotional_risk_calculation Step 0 - Initializing and starting Logging Process.

# %%
solution_definition = ''' 
Poor emotional regulatory control refers to the inability or difficulty in managing and regulating one's emotions effectively.
It involves challenges in recognizing, understanding, and appropriately responding to emotions
, often resulting in impulsive or inappropriate reactions to situations.
'''
talking_code = True
if talking_code:
    tc.print_say(solution_definition)
# Out:
#
# Poor emotional regulatory control refers to the inability or difficulty in managing and regulating one's emotions effectively.
# It involves challenges in recognizing, understanding, and appropriately responding to emotions
# , often resulting in impulsive or inappropriate reactions to situations.

# %%
supporting_definition = ''' 

The Transtheoretical Model (TTM) of behavior change, developed by Prochaska and DiClemente in the late 1970s, proposes that individuals progress through a series of stages when making changes in their behavior. These stages include Precontemplation, Contemplation, Preparation, Action, Maintenance, and Termination. In the Precontemplation stage, individuals are not considering change and may be unaware of the need for it. In Contemplation, individuals begin to recognize the problem and consider making changes in the near future. The Preparation stage involves taking initial steps toward change, such as setting goals or seeking support. Action is the stage where individuals actively modify their behavior, implementing strategies to achieve their goals. Maintenance involves sustaining the behavior change over time, with the ultimate goal being Termination, where the new behavior becomes ingrained, and the individual no longer feels tempted to return to old habits.

One of the key aspects of the Transtheoretical Model is the recognition that behavior change is not a linear process, and individuals may cycle through the stages multiple times before achieving lasting change. The model emphasizes the importance of tailoring interventions to match an individual's stage of change, as strategies that are effective in one stage may not be as beneficial in another. Additionally, the TTM acknowledges the influence of both internal and external factors, such as self-efficacy, social support, and environmental cues, on behavior change efforts. By understanding the stages of change and addressing the specific needs and challenges of individuals at each stage, practitioners can design more effective interventions to facilitate lasting behavior change.
'''
talking_code = True
if talking_code:
    tc.print_say(supporting_definition)
# Out:
#
#
# The Transtheoretical Model (TTM) of behavior change, developed by Prochaska and DiClemente in the late 1970s, proposes that individuals progress through a series of stages when making changes in their behavior. These stages include Precontemplation, Contemplation, Preparation, Action, Maintenance, and Termination. In the Precontemplation stage, individuals are not considering change and may be unaware of the need for it. In Contemplation, individuals begin to recognize the problem and consider making changes in the near future. The Preparation stage involves taking initial steps toward change, such as setting goals or seeking support. Action is the stage where individuals actively modify their behavior, implementing strategies to achieve their goals. Maintenance involves sustaining the behavior change over time, with the ultimate goal being Termination, where the new behavior becomes ingrained, and the individual no longer feels tempted to return to old habits.
#
# ...

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-03-17 20:42:46,805 - INFO - START poor_emotional_risk_calculation =============================================
# 2024-03-17 20:42:46,805 - INFO - START poor_emotional_risk_calculation Start Time = 2024-03-17 20:42:46
# 2024-03-17 20:42:46,805 - INFO - poor_emotional_risk_calculation Step 0 - Initialize the configuration file parser
# 2024-03-17 20:42:46,806 - INFO - Process poor_emotional_risk_calculation Step 0 - Initializing and starting Logging Process.
# 2024-03-17 20:42:46,820 - INFO - PERFORMANCE poor_emotional_risk_calculation The total process duration was:0.02
# 2024-03-17 20:42:46,820 - INFO - PERFORMANCE poor_emotional_risk_calculation Stop Time = 2024-03-17 20:42:46
# 2024-03-17 20:42:46,821 - INFO - PERFORMANCE poor_emotional_risk_calculation Short process duration less than 3 Seconds:0.02
# 2024-03-17 20:42:46,821 - INFO - PERFORMANCE poor_emotional_risk_calculation Performance optimization is not reccomended
# ...

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
